# %% [markdown]
# # Titre

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Quel est le code binaire correspondant au decimal 18 ?

# %% [markdown]
# Répondre ici

# %%
# correction
bin(18)[2:]
# Out:
# '10010'
