# %%
from IPython.display import Javascript

Javascript("""
function repeter(){
IPython.notebook.kernel.execute("kernel_survivor = 1");
}
// execute kernel_survivor = 1 en python toutes les 8 minutes pendant 2h

let timerId = setInterval(() => repeter(), 4800);
setTimeout(() => { clearInterval(timerId); alert('fin de cession, sauvegardez et téléchargez votre fichier'); }, 7200000);
""")

# %% [markdown]
# # Titre

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Quel est le code binaire correspondant au decimal 18 ?

# %% [markdown]
# Répondre ici

# %%
# correction
bin(18)[2:]
# Out:
# '10010'
